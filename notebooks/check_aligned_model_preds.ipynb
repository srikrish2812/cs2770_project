# %%
import pandas as pd
df = pd.read_csv("../data/aligned_vqa_rad_results_all.csv")

# Show 10 closed-ended examples
print("=== CLOSED ===")
for _, r in df[df['answer_type']=='CLOSED'].head(10).iterrows():
    print(f"Q: {r['question']}")
    print(f"GT: {r['gt_normalized']}  |  Pred: {r['pred_normalized']}\n")

# Show 10 open-ended examples
print("=== OPEN ===")
for _, r in df[df['answer_type']=='OPEN'].head(10).iterrows():
    print(f"Q: {r['question']}")
    print(f"GT: {r['gt_normalized']}  |  Pred: {r['pred_normalized']}\n")
# Out:
# === CLOSED ===
# Q: Are regions of the brain infarcted?
# GT: yes  |  Pred: yes
#
# Q: Are the lungs normal appearing?
# GT: no  |  Pred: yes
#
# Q: Is there evidence of a pneumothorax
# GT: no  |  Pred: yes.
#
# the common region of the brain, such as the cerebellum, cerebral cortex, or cerebral ventricles, is affected by the cerebral hemorrhage. the region
#
# Q: Is this a MRI of the chest?
# GT: no  |  Pred: yes
#
# Q: Is the trachea midline?
# GT: yes  |  Pred: yes
#
# Q: Is there evidence of an aortic aneurysm?
# GT: no  |  Pred: no
#
# Q: Is there blunting of the costovertebral angles?
# GT: no  |  Pred: yes
#
# Q: Is there a pneumothorax?
# GT: no  |  Pred: yes
#
# Q: Is there a fracture?
# GT: no  |  Pred: yes
#
# Q: Is there swelling of the grey matter?
# GT: yes  |  Pred: yes
#
# === OPEN ===
# Q: What type of imaging does this not represent?
# GT: ultrasound  |  Pred: 1
#
# Q: What is not pictured in this image?
# ...
